# %%
import pandas as pd
import numpy as np

import os
import pathlib
import re

import matplotlib

# %%
combinedData = pd.DataFrame()
files = [str(pathlib.Path("./original_data/") / f) for f in os.listdir("./original_data")]
for file in files:
    year = int(re.findall('\\d+', file)[0])
    df = pd.read_csv(file)
    df["year"] = year
    combinedData = pd.concat([combinedData, df], ignore_index=True)

# %%
combinedData
# Out:
#                  Player  Pos            School        College    Ht     Wt  \
# 0        Seyi Ajirotutu   WR      Fresno State  College Stats   6-3  204.0
# 1            Rahim Alem   DE               LSU  College Stats   6-3  251.0
# 2     Charles Alexander   DT               LSU  College Stats   6-4  300.0
# 3     Danario Alexander   WR          Missouri  College Stats   6-5  215.0
# 4            Nate Allen    S     South Florida  College Stats   6-0  207.0
# ...                 ...  ...               ...            ...   ...    ...
# 5386      Hunter Wohler  SAF         Wisconsin  College Stats   6-2  213.0
# 5387     Ernest Woodard   LB              UNLV  College Stats   6-2  234.0
# 5388      Craig Woodson  SAF        California  College Stats   6-0  200.0
# 5389       Marcus Yarns   RB          Delaware            NaN  5-11  193.0
# 5390         Grey Zabel   OT  North Dakota St.            NaN   6-6  312.0
#
#       40yd  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# ...

# %%
combinedData.drop(["College"], axis="columns", inplace=True)

# %%
print(combinedData["Ht"])
# Out:
# 0        6-3
# 1        6-3
# 2        6-4
# 3        6-5
# 4        6-0
#         ...
# 5386     6-2
# 5387     6-2
# 5388     6-0
# 5389    5-11
# 5390     6-6
# Name: Ht, Length: 5391, dtype: object

# %%
from numpy import isnan


def convert_height(height_string) -> int:
    feet, inches = height_string.split("-")
    feet, inches = int(feet), int(inches)
    total = 12 * feet + inches
    return total

combinedData["Ht"] = combinedData["Ht"].apply(lambda h: convert_height(h) if pd.notna(h) else h)

# %%
combinedData.to_csv("./combine_2010_2025")

# %%
# Out:
#     index               Player Pos             School   Ht     Wt  40yd  \
# 0    1847         Josue Matias  OG      Florida State  6-5  309.0  5.52
# 1    2270        Landon Turner  OG     North Carolina  6-4  330.0  5.58
# 2    2659        Orlando Brown  OT           Oklahoma  6-8  345.0  5.85
# 3    2398        Avery Gennesy  OG          Texas A&M  6-3  318.0  5.35
# 4    4161     Myron Cunningham  OT           Arkansas  6-5  320.0  5.38
# 5    4237            Ed Ingram  OG                LSU  6-3  307.0  5.02
# 6    1517     Daniel McCullers  DT          Tennessee  6-7  352.0  5.18
# 7    2445         Jarron Jones  DT         Notre Dame  6-6  316.0  5.33
# 8    2560         David Sharpe  OT            Florida  6-6  343.0  5.44
# 9    2608         Chad Wheeler  OT                USC  6-7  306.0  5.48
# 10   1105         Mark Jackson  OG    Glenville State  6-5  328.0  5.65
# 11     61        Terrence Cody  DT            Alabama  6-4  354.0  5.71
# ...
